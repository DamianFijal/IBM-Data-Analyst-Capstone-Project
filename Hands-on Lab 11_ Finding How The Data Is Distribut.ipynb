# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify the distribution of data in the dataset.
#
# *   Identify outliers in the dataset.
#
# *   Remove outliers from the dataset.
#
# *   Identify correlation between features in the dataset.

# %% [markdown]
# ***

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# 4  The quality of OSS and closed source software ...  Employed full-time
#
#           Country Student                                            EdLevel  \
# 0   United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1     New Zealand      No  Some college/university study without earning ...
# 2   United States      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3  United Kingdom      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4       Australia      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0  Computer science, computer engineering, or sof...  ...
# 1  Computer science, computer engineering, or sof...  ...
# 2  Computer science, computer engineering, or sof...  ...
# 3                                                NaN  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                               WelcomeChange  \
# 0   Just as welcome now as I felt last year
# 1   Just as welcome now as I felt last year
# 2  Somewhat more welcome now than last year
# 3   Just as welcome now as I felt last year
# 4   Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  22.0    Man    No
# 1                                                NaN  23.0    Man    No
# 2  Tech articles written by other developers;Cour...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  26.0    Man    No
# 4  Tech articles written by other developers;Indu...  29.0    Man    No
#
#                  Sexuality                              Ethnicity Dependents  \
# 0  Straight / Heterosexual           White or of European descent         No
# 1                 Bisexual           White or of European descent         No
# 2  Straight / Heterosexual           White or of European descent        Yes
# 3  Straight / Heterosexual           White or of European descent         No
# 4  Straight / Heterosexual  Hispanic or Latino/Latina;Multiracial         No
#
#             SurveyLength                  SurveyEase
# 0  Appropriate in length                        Easy
# 1  Appropriate in length  Neither easy nor difficult
# 2  Appropriate in length                        Easy
# 3  Appropriate in length  Neither easy nor difficult
# 4  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here

sns.distplot(df['ConvertedComp'])

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here

plt.hist(df['ConvertedComp'])
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([9659.,  238.,  115.,  125.,   99.,  131.,   34.,   15.,   15.,
#          151.]),
#  array([      0.,  200000.,  400000.,  600000.,  800000., 1000000.,
#         1200000., 1400000., 1600000., 1800000., 2000000.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here

df['ConvertedComp'].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here

df[df['Gender'] == 'Man']['ConvertedComp'].value_counts().sum()
# Out:
# 9725

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here

df[df['Gender'] == 'Woman']['ConvertedComp'].median()
# Out:
# 57708.0

# %%
#What is the median age of the Age of Survey respondednts? 

df['Age'].median()
# Out:
# 29.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here

df['Age'].describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here

plt.hist(df['Age'])
# Out:
# (array([2.094e+03, 5.337e+03, 2.557e+03, 8.420e+02, 2.250e+02, 4.900e+01,
#         6.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([16. , 24.3, 32.6, 40.9, 49.2, 57.5, 65.8, 74.1, 82.4, 90.7, 99. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here

sns.boxplot(y = 'ConvertedComp', data = df)

# %%
#
sns.boxplot(y = 'Age', data = df)

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here

quartile_1 = df['ConvertedComp'].quantile(q = 0.25)
quartile_3 = df['ConvertedComp'].quantile(q = 0.75)
iqr = quartile_3 - quartile_1
print(iqr)
print(quartile_1)
print(quartile_3)
# Out:
# 73132.0
# 26868.0
# 100000.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here

quart_1 = df['ConvertedComp'].quantile(q = 0.25)
quart_3 = df['ConvertedComp'].quantile(q = 0.75)
iqr = quart_3 - quart_1
lower_range = quart_1 - (1.5 * iqr)
upper_range = quart_3 + (1.5 * iqr)

print(lower_range)
print(upper_range)
# Out:
# -82830.0
# 209698.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here

lower_bound = df['ConvertedComp'] < lower_range
upper_bound = df['ConvertedComp'] > upper_range
no_of_outliers = df[lower_bound | upper_bound]

print(len(no_of_outliers))
# Out:
# 879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here

#new_df = df.drop(df[df['ConvertedComp'] < lower_bound | df['ConvertedComp'] > upper_bound], inplace = True)

x = df['ConvertedComp'].clip(lower_range, upper_range)
new_df = df[df['ConvertedComp'] == x ]
len(new_df)
# Out:
# 9703

# %%
#What is the median ConvertedComp after removing outliers?
new_df['ConvertedComp'].median()
# Out:
# 52704.0

# %%
#What is the mean ConvertedComp after removing outliers? 
new_df['ConvertedComp'].mean()
# Out:
# 59883.20838915799

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here

df['Age'].corr(df['ConvertedComp'])
# Out:
# 0.10538616072629149

# %%
#Which column has a negative correlation with "Age"? 
df.corr().style.background_gradient(cmap = 'coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col2 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col4 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col5 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col2 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col3 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col4 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col5 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col0 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col1 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col3 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col5 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row3_col1 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row3_col2 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row3_col4 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row3_col5 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row4_col0 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row4_col1 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row4_col3 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row5_col0 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row5_col1 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row5_col2 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row5_col3 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row5_col4 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Respondent</th>        <th class="col_heading level0 col1" >CompTotal</th>        <th class="col_heading level0 col2" >ConvertedComp</th>        <th class="col_heading level0 col3" >WorkWeekHrs</th>        <th class="col_heading level0 col4" >CodeRevHrs</th>        <th class="col_heading level0 col5" >Age</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5level0_row0" class="row_heading level0 row0" >Respondent</th>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col1" class="data row0 col1" >-0.01</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col2" class="data row0 col2" >0.00</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col3" class="data row0 col3" >-0.02</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col4" class="data row0 col4" >0.00</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row0_col5" class="data row0 col5" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5level0_row1" class="row_heading level0 row1" >CompTotal</th>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col0" class="data row1 col0" >-0.01</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col2" class="data row1 col2" >0.00</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col3" class="data row1 col3" >0.00</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col4" class="data row1 col4" >0.01</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row1_col5" class="data row1 col5" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5level0_row2" class="row_heading level0 row2" >ConvertedComp</th>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col0" class="data row2 col0" >0.00</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col1" class="data row2 col1" >0.00</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col3" class="data row2 col3" >0.02</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col4" class="data row2 col4" >-0.03</td>
#                         <td id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5row2_col5" class="data row2 col5" >0.11</td>
#             </tr>
#             <tr>
#                         <th id="T_a05e2272_d103_11eb_ac62_7b5f4dfac7e5level0_row3" class="row

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer\&utm_source=Exinfluencer\&utm_content=000026UJ\&utm_term=10006555\&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01\&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264\&cm_mmca1=000026UJ\&cm_mmca2=10006555\&cm_mmca3=M12345678\&cvosrc=email.Newsletter.M12345678\&cvo_campaign=000026UJ).
